# %% [markdown]
# # Read data from R and process

# %%
df <- read.csv("C:/Users/stati/OneDrive/Desktop/Research/windows10_dataset.csv")
df <- na.omit(df)

# %%
df = Filter(function(x)(length(unique(x))>1), df)

# %%
write.csv(df,'C:/Users/stati/OneDrive/Desktop/Research/windows10_dataset_processed.csv')

# %% [markdown]
# # Required Libraries

# %% [markdown]
# We are going to use Windows 10 system generated values to predict whether the system is under cyber attack or not !

# %%
import numpy as np
from numpy.ma.core import ceil
from scipy.spatial import distance #distance calculation
from sklearn.preprocessing import MinMaxScaler #normalisation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors

# %% [markdown]
# # Loading the data and EDA

# %%
# Set the working directory
import os
os.chdir("C:/Users/stati/OneDrive/Desktop/Research")

# %%
import pandas as pd
df = pd.read_csv('windows10_dataset_processed.csv',encoding='latin-1')

# %%
#df = df.drop(columns=df.columns[0], axis=1, inplace=True)
df.columns
# Out:
# Index(['ï..ts', 'Processor_DPC_Rate', 'Processor_pct_.Idle_Time',
#        'Processor_pct_.Interrupt_Time', 'Processor_pct_.User_Time',
#        'Processor_pct_.C1_Time', 'Processor_pct_.Processor_Time',
#        'Processor_C1_ransitions_sec', 'Processor_pct_.DPC_Time',
#        'Processor_pct_.Privileged_Time',
#        ...
#        'LogicalDisk._Total..Avg..Disk.Write.Queue.Length',
#        'LogicalDisk._Total..Avg..Disk.Queue.Length',
#        'LogicalDisk._Total..pct_.Disk.Read.Time',
#        'LogicalDisk._Total..Disk.Write.Bytes.sec',
#        'LogicalDisk._Total..Disk.Transfers.sec',
#        'LogicalDisk._Total..Avg..Disk.Bytes.Transfer',
#        'LogicalDisk._Total..pct_.Disk.Write.Time',
#        'LogicalDisk._Total..Avg..Disk.sec.Transfer', 'label', 'type'],
#       dtype='object', length=108)

# %%
df = df.drop('ï..ts', axis=1)

# %%
# Attack counts by type:
pd.crosstab(index=df['label'], columns=df['type'])
# Out:
# type   ddos  dos  injection  mitm  normal  password  scanning   xss
# label
# 0         0    0          0     0   24283         0         0     0
# 1      4539  505        606    13       0      3594       434  1240

# %%
# Remove the label column:
df = df.drop(['type'],axis=1)

# %%
df.head()
# Out:
#    Processor_DPC_Rate  Processor_pct_.Idle_Time  \
# 0                   4                 29.908172
# 1                   9                 31.751682
# 2                   5                 29.495167
# 3                  12                 18.224375
# 4                  12                 14.861187
#
#    Processor_pct_.Interrupt_Time  Processor_pct_.User_Time  \
# 0                       0.078240                 61.027509
# 1                       0.312521                 59.144594
# 2                       1.168222                 46.027940
# 3                       1.097192                 47.806219
# 4                       1.562431                 41.873151
#
#    Processor_pct_.C1_Time  Processor_pct_.Processor_Time  \
# 0               29.908172                      66.200149
# 1               31.751682                      66.247735
# 2               29.495167                      66.900381
# 3               18.224375                      79.545208
# 4               14.861187                      82.735137
#
#    Processor_C1_ransitions_sec  Processor_pct_.DPC_Time  \
# 0                   480.094991                 0.078240
# 1                   427.041284                 0.078130
# 2                  1159.426821                 0.233644
# 3                   736.622011                 0.313483
# 4                   896.108598                 0.703094
#
#    Processor_pct_.Privileged_Time  Processor_DPCs_Queued_sec  ...  \
# 0                        5.163866                 568.322711  ...
# 1                        7.109852                 512.249521  ...
# 2                       20.872230                 917.339935  ...
# 3                       31.740194                 894.340589  ...
# 4                       40.857571                1381.842235  ...
#
#    LogicalDisk._Total..Avg..Disk.Bytes.Read  \
# 0                               20546.65089
# 1                               25742.31139
# 2                               35969.10535
# 3                               40019.44778
# 4                               32025.59015
#
#    LogicalDisk._Total..Avg..Disk.Write.Queue.Length  \
# 0                                          0.134876
# 1                                          0.157564
# 2                                          0.401774
# 3                                          0.259062
# 4                                          0.103836
#
#    LogicalDisk._Total..Avg..Disk.Queue.Length  \
# 0                                    0.163098
# 1                                    0.189279
# 2                                    0.782472
# 3                                    0.768934
# 4                                    1.081730
#
#    LogicalDisk._Total..pct_.Disk.Read.Time  \
# 0                                 2.822198
# 1                                 3.171506
# 2                                38.069810
# 3                                50.987167
# 4                                97.789353
#
#    LogicalDisk._Total..Disk.Write.Bytes.sec  \
# 0                              1.924988e+06
# 1                              1.497233e+06
# 2                              1.854229e+06
# 3                              1.591239e+07
# 4                              2.360930e+07
#
#    LogicalDisk._Total..Disk.Transfers.sec  \
# 0                              402.582784
# 1                              355.134332
# 2                              760.431768
# 3                              699.499954
# 4                             1184.550425
#
#    LogicalDisk._Total..Avg..Disk.Bytes.Transfer  \
# 0                                   9100.481592
# 1                                  11153.554490
# 2                                  26994.265950
# 3                                  53141.663800
# 4                                  40988.684440
#
#    LogicalDisk._Total..pct_.Disk.Write.Time  \
# 0                                 13.487612
# 1                                 15.756429
# 2                                 40.177378
# 3                                 25.906233
# 4                                 10.383619
#
#    LogicalDisk._Total..Avg..Disk.sec.Transfer  label
# 0                                    0.000405      0
# 1                                    0.000533      0
# 2                                    0.001028      0
# 3                                    0.001099      0
# 4                                    0.000913      0
#
# [5 rows x 106 columns]

# %% [markdown]
# # Making the data balance

# %%
freq = df['label'].value_counts()
freq
# Out:
# 0    24283
# 1    10931
# Name: label, dtype: int64

# %%
delete_frac = round((freq[0] - freq[1])/freq[0],2)

# %%
df = df.drop(df.query('label == 0').sample(frac= delete_frac).index)

# %%
df['label'].value_counts()
# Out:
# 1    10931
# 0    10927
# Name: label, dtype: int64

# %% [markdown]
# ## Checking column types and converting them in the right format:

# %%
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21858 entries, 3 to 35213
# Columns: 106 entries, Processor_DPC_Rate to label
# dtypes: float64(74), int64(32)
# memory usage: 17.8 MB
# None
# (21858, 106)

# %% [markdown]
# So, there a total of 125 features presented in this data file and number of rows are 35,975!

# %%
columns = df.applymap(np.isreal).all()
print((columns).value_counts())
# Out:
# True    106
# dtype: int64

# %% [markdown]
# So, there are a total of 69 categorical and 56 numerical columns available in this data file. We need to investigate that, the 69 categorical variables whether they are really categorical or there are some problem in data types for them.

# %%
# Now considering blank space as missing entry and recategorizing the numerical object columns to actual number columns
df.replace(r'^\s*$', np.nan, regex=True)
# Out:
#        Processor_DPC_Rate  Processor_pct_.Idle_Time  \
# 3                      12                 18.224375
# 5                      19                 22.657346
# 6                       9                 19.296817
# 11                     13                 48.525733
# 13                     17                 50.849749
# ...                   ...                       ...
# 35206                   2                 18.293129
# 35208                   2                 47.080046
# 35211                   0                 95.294715
# 35212                   0                 94.927619
# 35213                   2                 93.519333
#
#        Processor_pct_.Interrupt_Time  Processor_pct_.User_Time  \
# 3                           1.097192                 47.806219
# 5                           0.781280                 39.454652
# 6                           2.734334                 35.077595
# 11                          0.625974                 29.029545
# 13                          0.469484                 32.942132
# ...                              ...                       ...
# 35206                       0.078248                 71.362589
# 35208                       0.000000                 46.498185
# 35211                       0.000000                  2.108141
# 35212                       0.000000                  0.859393
# 35213                       0.000000                  1.798663
#
#        Processor_pct_.C1_Time  Processor_pct_.Processor_Time  \
# 3                   18.224375                      79.545208
# 5                   22.657346                      74.061496
# 6                   19.296817                      75.781616
# 11                  48.525733                      48.200650
# 13                  50.849749                      46.009332
# ...                       ...                            ...
# 35206               18.293129                      80.437887
# 35208               47.080046                      51.235517
# 35211               95.294715                       2.088548
# 35212               94.927619                       2.810513
# 35213               93.519333                       3.732440
#
#        Processor_C1_ransitions_sec  Processor_pct_.DPC_Time  \
# 3                       736.622011                 0.313483
# 5                       807.794015                 0.234384
# 6                      1665.275721                 0.624991
# 11                     1782.461297                 0.078247
# 13                     1281.802760                 0.156495
# ...                            ...                      ...
# 35206                   117.170943                 0.391242
# 35208                   180.027051                 0.156296
# 35211                   263.642684                 0.000000
# 35212                   342.110790                 0.000000
# 35213                   347.143207                 0.000000
#
#        Processor_pct_.Privileged_Time  Processor_DPCs_Queued_sec  ...  \
# 3                           31.740194                 894.340589  ...
# 5                           34.610715                 955.502633  ...
# 6                           40.702510                1290.768735  ...
# 11                          19.170454                1832.138254  ...
# 13                          13.067307                 903.912323  ...
# ...                               ...                        ...  ...
# 35206                        9.076821                 165.741804  ...
# 35208                        4.767041                 105.615870  ...
# 35211                        0.078079                  29.482408  ...
# 35212                        1.953165                  43.001356  ...
# 35213                        1.876866                  73.672837  ...
#
#        LogicalDisk._Total..Avg..Disk.Bytes.Read  \
# 3                                   40019.44778
# 5                                   36368.13317
# 6                                   16248.93350
# 11                                  15671.41307
# 13                                  91405.79228
# ...                                         ...
# 35206                                   0.00000
# 35208                                   0.00000
# 35211                                   0.00000
# 35212                                   0.00000
# 35213                               16384.00000
#
#        LogicalDisk._Total..Avg..Disk.Write.Queue.Length  \
# 3                                              0.259062
# 5                                              0.151794
# 6                                              0.072069
# 11                                             0.000504
# 13                                             0.007903
# ...                                                 ...
# 35206                                          0.000421
# 35208                                          0.000087
# 35211                                          0.000168
# 35212                                          0.000440
# 35213                                          0.000462
#
#        LogicalDisk._Total..Avg..Disk.Queue.Length  \
# 3                                        0.768934
# 5                                        0.804626
# 6                                        1.082287
# 11                                       0.499560
# 13                                       0.553646
# ...                                           ...
# 35206                                    0.000421
# 35208                                    0.000087
# 35211                                    0.000168
# 35212                                    0.000440
# 35213                                    0.000733
#
#        LogicalDisk._Total..pct_.Disk.Read.Time  \
# 3                                    50.987167
# 5                                    65.283183
# 6                                   101.021753
# 11                                   49.905618
# 13                                   54.574281
# ...                                        ...
# 35206                                 0.000000
# 35208                                 0.000000
# 35211                                 0.000000
# 35212                                 0.000000
# 35213                                 0.009060
#
#        LogicalDisk._Total..Disk.Write.Bytes.sec  \
# 3                                  1.591239e+07
# 5                                  1.283909e+07
# 6                                  2.044406e+07
# 11                                 2.953696e+04
# 13                                 3.325003e+05
# ...                                         ...
# 35206                              1.394675e+04
# 35208                              9.422216e+03
# 35211                              9.824538e+03
# 35212                              2.129987e+04
# 35213                              1.435019e+04
#
#        LogicalDisk._Total..Disk.Transfers.sec  \
# 3                                  699.499954
# 5                                  788.780033
# 6                                 1103.615271
# 11                                1653.962233
# 13                                 711.010923
# ...                                       ...
# 35206                                0.901315
# 35208                                0.400060
# 35211                                0.499702
# 35212                                1.500047
# 35213                                1.801781
#
#        LogicalDisk._Total..Avg..Disk.Bytes.Transfer  \
# 3                                      53141.663800
# 5                                      47320.635370
# 6                                      32610.079580
# 11                                     15656.057160
# 13                                     86504.199460
# ...                                             ...
# 35206                                  15473.777780
# 35208                                  23552.000000
# 35211                                  19660.800000
# 35212                                  14199.466670
# 35213                                   8874.666667
#
#        LogicalDisk._Total..pct_.Disk.Write.Time  \
# 3                                     25.906233
# 5                                     15.179443
# 6                                      7.206940
# 11                                     0.050356
# 13                                     0.790296
# ...                                         ...
# 35206                                  0.014043
# 35208                                  0.002909
# 35211                                  0.005594
# 35212                                  0.014671
# 35213                                  0.015387
#
#        LogicalDisk._Total..Avg..Disk.sec.Transfer  label
# 3                                        0.001099      0
# 5                                        0.001021      0
# 6                                        0.000981      0
# 11                                       0.000302      0
# 13                                       0.000779      0
# ...                                           ...    ...
# 35206                                    0.000467      0
# 35208                                    0.000218      0
# 35211                                    0.000336      0
# 35212                                    0.000293      0
# 35213                                    0.000407      0
#
# [21858 rows x 106 columns]

# %%
# Keeping the object columns only to convert them as numberical because they actualy is a numerical column but
# because of space available in the entry python considering this column as an object type.

object_colmns = list(df.select_dtypes(include=['object']).columns)
#object_colmns.remove('type')

# %%
df[object_colmns] = df[object_colmns].apply(pd.to_numeric, errors='coerce')

# %%
# Checking:
columns = df.applymap(np.isreal).all()
print((columns).value_counts())
# Out:
# True    106
# dtype: int64

# %%
df.head()
# Out:
#     Processor_DPC_Rate  Processor_pct_.Idle_Time  \
# 3                   12                 18.224375
# 5                   19                 22.657346
# 6                    9                 19.296817
# 11                  13                 48.525733
# 13                  17                 50.849749
#
#     Processor_pct_.Interrupt_Time  Processor_pct_.User_Time  \
# 3                        1.097192                 47.806219
# 5                        0.781280                 39.454652
# 6                        2.734334                 35.077595
# 11                       0.625974                 29.029545
# 13                       0.469484                 32.942132
#
#     Processor_pct_.C1_Time  Processor_pct_.Processor_Time  \
# 3                18.224375                      79.545208
# 5                22.657346                      74.061496
# 6                19.296817                      75.781616
# 11               48.525733                      48.200650
# 13               50.849749                      46.009332
#
#     Processor_C1_ransitions_sec  Processor_pct_.DPC_Time  \
# 3                    736.622011                 0.313483
# 5                    807.794015                 0.234384
# 6                   1665.275721                 0.624991
# 11                  1782.461297                 0.078247
# 13                  1281.802760                 0.156495
#
#     Processor_pct_.Privileged_Time  Processor_DPCs_Queued_sec  ...  \
# 3                        31.740194                 894.340589  ...
# 5                        34.610715                 955.502633  ...
# 6                        40.702510                1290.768735  ...
# 11                       19.170454                1832.138254  ...
# 13                       13.067307                 903.912323  ...
#
#     LogicalDisk._Total..Avg..Disk.Bytes.Read  \
# 3                                40019.44778
# 5                                36368.13317
# 6                                16248.93350
# 11                               15671.41307
# 13                               91405.79228
#
#     LogicalDisk._Total..Avg..Disk.Write.Queue.Length  \
# 3                                           0.259062
# 5                                           0.151794
# 6                                           0.072069
# 11                                          0.000504
# 13                                          0.007903
#
#     LogicalDisk._Total..Avg..Disk.Queue.Length  \
# 3                                     0.768934
# 5                                     0.804626
# 6                                     1.082287
# 11                                    0.499560
# 13                                    0.553646
#
#     LogicalDisk._Total..pct_.Disk.Read.Time  \
# 3                                 50.987167
# 5                                 65.283183
# 6                                101.021753
# 11                                49.905618
# 13                                54.574281
#
#     LogicalDisk._Total..Disk.Write.Bytes.sec  \
# 3                               1.591239e+07
# 5                               1.283909e+07
# 6                               2.044406e+07
# 11                              2.953696e+04
# 13                              3.325003e+05
#
#     LogicalDisk._Total..Disk.Transfers.sec  \
# 3                               699.499954
# 5                               788.780033
# 6                              1103.615271
# 11                             1653.962233
# 13                              711.010923
#
#     LogicalDisk._Total..Avg..Disk.Bytes.Transfer  \
# 3                                    53141.66380
# 5                                    47320.63537
# 6                                    32610.07958
# 11                                   15656.05716
# 13                                   86504.19946
#
#     LogicalDisk._Total..pct_.Disk.Write.Time  \
# 3                                  25.906233
# 5                                  15.179443
# 6                                   7.206940
# 11                                  0.050356
# 13                                  0.790296
#
#     LogicalDisk._Total..Avg..Disk.sec.Transfer  label
# 3                                     0.001099      0
# 5                                     0.001021      0
# 6                                     0.000981      0
# 11                                    0.000302      0
# 13                                    0.000779      0
#
# [5 rows x 106 columns]

# %% [markdown]
# Now, only the response variable seems categorical. So, we are good about our actual column types for the dataframe.

# %% [markdown]
# ## Summary statistics for numerical columns

# %%
df.describe()
# Out:
#        Processor_DPC_Rate  Processor_pct_.Idle_Time  \
# count        35214.000000              35214.000000
# mean             5.668314                 72.035438
# std             18.716827                 20.546655
# min              0.000000                  0.000000
# 25%              0.000000                 62.589187
# 50%              0.000000                 74.940266
# 75%              1.000000                 89.113131
# max            195.000000                 99.638956
#
#        Processor_pct_.Interrupt_Time  Processor_pct_.User_Time  \
# count                   35214.000000              35214.000000
# mean                        0.167905                 17.098864
# std                         0.359206                 13.988805
# min                         0.000000                  0.000000
# 25%                         0.000000                  5.318951
# 50%                         0.000000                 14.509127
# 75%                         0.234013                 25.117544
# max                        10.641964                 91.566420
#
#        Processor_pct_.C1_Time  Processor_pct_.Processor_Time  \
# count            35214.000000                   35214.000000
# mean                72.035438                      25.426923
# std                 20.546655                      20.338239
# min                  0.000000                       0.000000
# 25%                 62.589187                       8.429947
# 50%                 74.940266                      22.928763
# 75%                 89.113131                      34.163972
# max                 99.638956                     100.000000
#
#        Processor_C1_ransitions_sec  Processor_pct_.DPC_Time  \
# count                 35214.000000             35214.000000
# mean                    551.725609                 0.513604
# std                     844.635668                 1.233437
# min                       0.000000                 0.000000
# 25%                     154.499255                 0.000000
# 50%                     307.176978                 0.078124
# 75%                     421.401051                 0.390012
# max                   10318.521390                21.953888
#
#        Processor_pct_.Privileged_Time  Processor_DPCs_Queued_sec  ...  \
# count                    35214.000000               35214.000000  ...
# mean                         8.325070                 379.435748  ...
# std                         10.807045                 963.693771  ...
# min                          0.000000                   3.794126  ...
# 25%                          1.326054                  25.561099  ...
# 50%                          2.968731                  38.258653  ...
# 75%                         12.748875                 248.320166  ...
# max                         81.182168                8141.157271  ...
#
#        LogicalDisk._Total..Avg..Disk.Bytes.Read  \
# count                              35214.000000
# mean                               14597.567963
# std                                23113.333385
# min                                    0.000000
# 25%                                    0.000000
# 50%                                 4096.000000
# 75%                                22753.681877
# max                               944383.062300
#
#        LogicalDisk._Total..Avg..Disk.Write.Queue.Length  \
# count                                      35214.000000
# mean                                           0.020388
# std                                            0.101185
# min                                            0.000000
# 25%                                            0.000361
# 50%                                            0.000799
# 75%                                            0.004369
# max                                            1.836753
#
#        LogicalDisk._Total..Avg..Disk.Queue.Length  \
# count                                35214.000000
# mean                                     0.137814
# std                                      0.417481
# min                                      0.000000
# 25%                                      0.000418
# 50%                                      0.001174
# 75%                                      0.007208
# max                                      4.364882
#
#        LogicalDisk._Total..pct_.Disk.Read.Time  \
# count                             35214.000000
# mean                                  4.391958
# std                                  14.523762
# min                                   0.000000
# 25%                                   0.000000
# 50%                                   0.001352
# 75%                                   0.053539
# max                                 294.529448
#
#        LogicalDisk._Total..Disk.Write.Bytes.sec  \
# count                              3.521400e+04
# mean                               1.177482e+06
# std                                3.328933e+06
# min                                0.000000e+00
# 25%                                1.146907e+04
# 50%                                2.707718e+04
# 75%                                2.029794e+05
# max                                6.051320e+07
#
#        LogicalDisk._Total..Disk.Transfers.sec  \
# count                            35214.000000
# mean                               234.204762
# std                                720.440340
# min                                  0.000000
# 25%                                  0.898604
# 50%                                  2.600066
# 75%                                 16.820502
# max                               7170.887411
#
#        LogicalDisk._Total..Avg..Disk.Bytes.Transfer  \
# count                                  35214.000000
# mean                                   25353.973162
# std                                    49029.709022
# min                                        0.000000
# 25%                                    11638.779422
# 50%                                    16384.000000
# 75%                                    24551.126710
# max                                   977715.200000
#
#        LogicalDisk._Total..pct_.Disk.Write.Time  \
# count                              35214.000000
# mean                                   1.576697
# std                                    9.926539
# min                                    0.000000
# 25%                                    0.012078
# 50%                                    0.026930
# 75%                                    0.148555
# max                                  183.675284
#
#        LogicalDisk._Total..Avg..Disk.sec.Transfer         label
# count                                35214.000000  35214.000000
# mean                                     0.000643      0.310416
# std                                      0.000945      0.462671
# min                                      0.000000      0.000000
# 25%                                      0.000307      0.000000
# 50%                                      0.000417      0.000000
# 75%                                      0.000656      1.000000
# max                                      0.045244      1.000000
#
# [8 rows x 106 columns]

# %% [markdown]
# We are observing that the range of the columns are highly fluctuating for the columns. So, definitely the data needs to be standardize or we have to normalize the columns before feeding them in the model. But before that, we are going to observe the missing value distribution over the columns.

# %% [markdown]
# ## Missing value % investigation and imputation:

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)

# %%
missing_value_df.tail()
# Out:
#                                                      column_name  \
# Process_Thread.Count                        Process_Thread.Count
# Process_IO.Data.Operations_sec    Process_IO.Data.Operations_sec
# Process_IO.Other.Operations_sec  Process_IO.Other.Operations_sec
# Process_Working.Set                          Process_Working.Set
# label                                                      label
#
#                                  percent_missing
# Process_Thread.Count                         0.0
# Process_IO.Data.Operations_sec               0.0
# Process_IO.Other.Operations_sec              0.0
# Process_Working.Set                          0.0
# label                                        0.0

# %% [markdown]
# The highest missing percentage is around 1.5% for Process_IO Read Bytes_sec column. So, we are good to go for missing value imputation. We will replace that missing entries by mean at this stage. Later we will check the performance after replacing with Median.

# %%
df.fillna(df.select_dtypes(include='number').mean(), inplace=True)

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True)

# %%
missing_value_df.tail()
# Out:
#                                                                                          column_name  \
# Process_ID Process                                                                Process_ID Process
# Process_Page Faults_sec                                                      Process_Page Faults_sec
# Process_Working Set                                                              Process_Working Set
# Network_I(Intel R _82574L_GNC) Bytes Received sec  Network_I(Intel R _82574L_GNC) Bytes Received sec
# label                                                                                          label
#
#                                                    percent_missing
# Process_ID Process                                             0.0
# Process_Page Faults_sec                                        0.0
# Process_Working Set                                            0.0
# Network_I(Intel R _82574L_GNC) Bytes Received sec              0.0
# label                                                          0.0

# %% [markdown]
# ## Seperating independent and dependent variables:

# %%
# Removing Y and Id
X = df.iloc [: ,:-1].values    # independent variables
# Keeping only Y
y = df.iloc [: , -1].values    # dependent variables

# %% [markdown]
# ## Handling Inf values:

# %%
import numpy as np

# find min and max values for each column, ignoring nan, -inf, and inf
mins = [np.nanmin(X[:, i][X[:, i] != -np.inf]) for i in range(X.shape[1])]
maxs = [np.nanmax(X[:, i][X[:, i] != np.inf]) for i in range(X.shape[1])]

# go through matrix one column at a time and replace  + and -infinity 
# with the max or min for that column
for i in range(X.shape[1]):
    X[:, i][X[:, i] == -np.inf] = mins[i]
    X[:, i][X[:, i] == np.inf] = maxs[i]

# %% [markdown]
# ## Standardizing all numerical columns

# %%
# feature Scaling
sc = MinMaxScaler(feature_range = (0,1))
X = sc.fit_transform(X)

# %% [markdown]
# # Train test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,test_size=0.2)

# %% [markdown]
# # Unsupervised modelling:

# %% [markdown]
# ## SOM

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Minisom library and module is used for performing Self Organizing Maps
from minisom import MiniSom

# %%
def classify(som, data):
    """Classifies each sample in data in one of the classes definited
    using the method labels_map.
    Returns a list of the same length of data where the i-th element
    is the class assigned to data[i].
    """
    winmap = som.labels_map(X_train, y_train)
    default_class = np.sum(list(winmap.values())).most_common()[0][0]
    result = []
    for d in data:
        win_position = som.winner(d)
        if win_position in winmap:
            result.append(winmap[win_position].most_common()[0][0])
        else:
            result.append(default_class)
    return result

# %%
# I use linear som topography
som_shape = (1, 2)
som = MiniSom(som_shape[0], som_shape[1], X_train.shape[1],sigma = 3, learning_rate=0.5, 
              neighborhood_function='triangle')
som.pca_weights_init(X_train)
som.train_random(X_train, 100, verbose=False)

print(classification_report(y_test, classify(som, X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.72      0.76      2186
#            1       0.74      0.82      0.78      2186
#
#     accuracy                           0.77      4372
#    macro avg       0.77      0.77      0.77      4372
# weighted avg       0.77      0.77      0.77      4372

# %% [markdown]
# ## K-means clustering

# %%
#Now let's open it with pandas
import pandas as pd
from pandas import Series,DataFrame
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

import numpy as np
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import metrics 


import warnings
warnings.filterwarnings('ignore')

# %%
def k_means_fit(covariates,centroid_method):
    data = pd.DataFrame(covariates)
    # from sklearn.cluster import KMeans 
    clusters = 2
    number_of_iteration = 100
    kmeans = KMeans(n_clusters = clusters,n_init= number_of_iteration,init = centroid_method,algorithm = "full") 
    kmeans.fit(data) 
    
    y_labels_test = kmeans.predict(X_test)
    tab = pd.crosstab(index=y_test, columns=y_labels_test)
    print (metrics.classification_report(y_test,y_labels_test))

# %%
k_means_fit(X_train,centroid_method = "random")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81      2186
#            1       0.76      1.00      0.86      2186
#
#     accuracy                           0.84      4372
#    macro avg       0.88      0.84      0.84      4372
# weighted avg       0.88      0.84      0.84      4372

# %% [markdown]
# # Result

# %% [markdown]
# For both SOM and K-means clustering giving us similar measure of accuracy measrure and between them k-means is slightly better and it's around 84%.
