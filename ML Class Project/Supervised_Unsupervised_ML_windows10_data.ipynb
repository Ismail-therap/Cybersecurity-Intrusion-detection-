# %% [markdown]
# # Read data from R and process

# %%
df <- read.csv("E:/Cybersecurity-Intrusion-detection--main/Cybersecurity-Intrusion-detection--main/ML Class Project/windows10_dataset.csv")
df <- na.omit(df)

# %%
df = Filter(function(x)(length(unique(x))>1), df)

# %%
dim(df)
# Out:
# [1] 35214   108

# %%
write.csv(df,'C:/Users/stati/OneDrive/Desktop/Research/windows10_dataset_processed.csv')

# %% [markdown]
# We removed the missing entries and remove the variables which have only a single value for all the etries or variability was zero.

# %% [markdown]
# # Required Libraries

# %% [markdown]
# We are going to use Windows 10 system generated values to predict whether the system is under cyber attack or not !

# %%
import numpy as np
from numpy.ma.core import ceil
from scipy.spatial import distance #distance calculation
from sklearn.preprocessing import MinMaxScaler #normalisation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score #scoring
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from matplotlib import animation, colors0
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-1585ae4fd7ef> in <module>
#       7 from sklearn.metrics import confusion_matrix
#       8 import matplotlib.pyplot as plt
# ----> 9 from matplotlib import animation, colors0
#
# ImportError: cannot import name 'colors0' from 'matplotlib' (C:\Users\DELL\anaconda3\lib\site-packages\matplotlib\__init__.py)

# %% [markdown]
# # Loading the data and EDA

# %%
# Set the working directory
import os
os.chdir("E:/Cybersecurity-Intrusion-detection--main/Cybersecurity-Intrusion-detection--main/ML Class Project")

# %%
import pandas as pd
df = pd.read_csv('windows10_dataset_processed.csv',encoding='latin-1')

# %%
#df

# %%
df = df.drop(df.columns[0],axis=1)

# %%
df = df.drop(df.columns[0],axis=1)

# %%
# Attack counts by type:
pd.crosstab(index=df['label'], columns=df['type'])
# Out:
# type   ddos  dos  injection  mitm  normal  password  scanning   xss
# label
# 0         0    0          0     0   24283         0         0     0
# 1      4539  505        606    13       0      3594       434  1240

# %%
# Remove the label column:
df = df.drop(['type'],axis=1)

# %%
df.head(20)
# Out:
#     Processor_DPC_Rate  Processor_pct_.Idle_Time  \
# 0                    4                 29.908172
# 1                    9                 31.751682
# 2                    5                 29.495167
# 3                   12                 18.224375
# 4                   12                 14.861187
# 5                   19                 22.657346
# 6                    9                 19.296817
# 7                    3                 28.374642
# 8                    3                 23.961375
# 9                    3                 61.473132
# 10                  52                 56.220035
# 11                  13                 48.525733
# 12                  14                 45.982727
# 13                  17                 50.849749
# 14                  37                 52.206083
# 15                   8                 32.874279
# 16                  25                 25.760493
# 17                   1                 80.419023
# 18                   1                 74.717785
# 19                   1                 74.631391
#
#     Processor_pct_.Interrupt_Time  Processor_pct_.User_Time  \
# 0                        0.078240                 61.027509
# 1                        0.312521                 59.144594
# 2                        1.168222                 46.027940
# 3                        1.097192                 47.806219
# 4                        1.562431                 41.873151
# 5                        0.781280                 39.454652
# 6                        2.734334                 35.077595
# 7                        0.312496                 52.186774
# 8                        0.624038                 39.626426
# 9                        0.704204                 21.047862
# 10                       0.780054                 23.323609
# 11                       0.625974                 29.029545
# 12                       0.702026                 32.995208
# 13                       0.469484                 32.942132
# 14                       0.702031                 26.443172
# 15                       0.938943                 35.836313
# 16                       0.702039                 32.995825
# 17                       0.156492                 15.023191
# 18                       0.156247                 19.765194
# 19                       0.312499                 20.156184
#
#     Processor_pct_.C1_Time  Processor_pct_.Processor_Time  \
# 0                29.908172                      66.200149
# 1                31.751682                      66.247735
# 2                29.495167                      66.900381
# 3                18.224375                      79.545208
# 4                14.861187                      82.735137
# 5                22.657346                      74.061496
# 6                19.296817                      75.781616
# 7                28.374642                      69.453550
# 8                23.961375                      72.854338
# 9                61.473132                      36.308699
# 10               56.220035                      37.127663
# 11               48.525733                      48.200650
# 12               45.982727                      47.426074
# 13               50.849749                      46.009332
# 14               52.206083                      42.979473
# 15               32.874279                      62.129311
# 16               25.760493                      70.280356
# 17               80.419023                      17.450693
# 18               74.717785                      24.064157
# 19               74.631391                      22.890879
#
#     Processor_C1_ransitions_sec  Processor_pct_.DPC_Time  \
# 0                    480.094991                 0.078240
# 1                    427.041284                 0.078130
# 2                   1159.426821                 0.233644
# 3                    736.622011                 0.313483
# 4                    896.108598                 0.703094
# 5                    807.794015                 0.234384
# 6                   1665.275721                 0.624991
# 7                    402.292858                 0.078124
# 8                   2141.205491                 0.234014
# 9                   2936.251094                 0.234735
# 10                  1427.130982                 0.078005
# 11                  1782.461297                 0.078247
# 12                  1220.200088                 0.000000
# 13                  1281.802760                 0.156495
# 14                  2051.310732                 0.234010
# 15                  1232.493070                 0.782452
# 16                  2383.748500                 0.156009
# 17                   485.825952                 0.156492
# 18                   582.888849                 0.546863
# 19                   432.897147                 0.468748
#
#     Processor_pct_.Privileged_Time  Processor_DPCs_Queued_sec  ...  \
# 0                         5.163866                 568.322711  ...
# 1                         7.109852                 512.249521  ...
# 2                        20.872230                 917.339935  ...
# 3                        31.740194                 894.340589  ...
# 4                        40.857571                1381.842235  ...
# 5                        34.610715                 955.502633  ...
# 6                        40.702510                1290.768735  ...
# 7                        17.265385                 475.491558  ...
# 8                        33.230035                 639.116640  ...
# 9                        15.257744                2955.981003  ...
# 10                       13.806952                1280.054515  ...
# 11                       19.170454                1832.138254  ...
# 12                       14.430529                 893.009540  ...
# 13                       13.067307                 903.912323  ...
# 14                       16.536733                1211.117020  ...
# 15                       26.290396                1151.468619  ...
# 16                       37.286062                1113.174518  ...
# 17                        2.425619                 322.915455  ...
# 18                        4.296781                 505.890322  ...
# 19                        2.734366                 275.298186  ...
#
#     LogicalDisk._Total..Avg..Disk.Bytes.Read  \
# 0                               20546.650890
# 1                               25742.311390
# 2                               35969.105350
# 3                               40019.447780
# 4                               32025.590150
# 5                               36368.133170
# 6                               16248.933500
# 7                               43995.891500
# 8                               46653.692920
# 9                                5065.711085
# 10                               6237.302519
# 11                              15671.413070
# 12                             107106.078400
# 13                              91405.792280
# 14                              40089.771470
# 15                              23125.248470
# 16                              35397.534080
# 17                              38604.165290
# 18                              21091.906440
# 19                              32791.735100
#
#     LogicalDisk._Total..Avg..Disk.Write.Queue.Length  \
# 0                                           0.134876
# 1                                           0.157564
# 2                                           0.401774
# 3                                           0.259062
# 4                                           0.103836
# 5                                           0.151794
# 6                                           0.072069
# 7                                           0.048437
# 8                                           0.098541
# 9                                           0.004243
# 10                                          0.020561
# 11                                          0.000504
# 12                                          0.009600
# 13                                          0.007903
# 14                                          0.005996
# 15                                          0.052345
# 16                                          0.041824
# 17                                          0.013336
# 18                                          0.018688
# 19                                          0.005519
#
#     LogicalDisk._Total..Avg..Disk.Queue.Length  \
# 0                                     0.163098
# 1                                     0.189279
# 2                                     0.782472
# 3                                     0.768934
# 4                                     1.081730
# 5                                     0.804626
# 6                                     1.082287
# 7                                     0.142110
# 8                                     0.251544
# 9                                     0.740462
# 10                                    0.648671
# 11                                    0.499560
# 12                                    0.452371
# 13                                    0.553646
# 14                                    0.519869
# 15                                    0.905200
# 16                                    1.287522
# 17                                    0.245272
# 18                                    0.141457
# 19                                    0.014216
#
#     LogicalDisk._Total..pct_.Disk.Read.Time  \
# 0                                  2.822198
# 1                                  3.171506
# 2                                 38.069810
# 3                                 50.987167
# 4                                 97.789353
# 5                                 65.283183
# 6                                101.021753
# 7                                  9.367386
# 8                                 15.300358
# 9                                 73.621908
# 10                                62.811001
# 11                                49.905618
# 12                                44.277125
# 13                                54.574281
# 14                                51.387239
# 15                                85.285454
# 16                               124.569786
# 17                                23.193613
# 18                                12.276900
# 19                                 0.869649
#
#     LogicalDisk._Total..Disk.Write.Bytes.sec  \
# 0                               1.924988e+06
# 1                               1.497233e+06
# 2                               1.854229e+06
# 3                               1.591239e+07
# 4                               2.360930e+07
# 5                               1.283909e+07
# 6                               2.044406e+07
# 7                               1.269656e+07
# 8                               1.462362e+07
# 9                               3.435608e+03
# 10                              6.107684e+06
# 11                              2.953696e+04
# 12                              2.441510e+06
# 13                              3.325003e+05
# 14                              9.487969e+04
# 15                              1.672139e+07
# 16                              1.592924e+07
# 17                              1.682567e+04
# 18                              5.293979e+04
# 19                              6.122968e+05
#
#     LogicalDisk._Total..Disk.Transfers.sec  \
# 0                               402.582784
# 1                               355.134332
# 2                               760.431768
# 3                               699.499954
# 4                              1184.550425
# 5                               788.780033
# 6                              1103.615271
# 7                               304.294597
# 8                               439.024507
# 9                              2808.056763
# 10                             1128.484878
# 11                             1653.962233
# 12                              704.303365
# 13                              711.010923
# 14                             1028.600787
# 15                              880.652655
# 16                              890.699310
# 17                              196.374276
# 18                              316.693942
# 19                               34.299774
#
#     LogicalDisk._Total..Avg..Disk.Bytes.Transfer  \
# 0                                    9100.481592
# 1                                   11153.554490
# 2                                   26994.265950
# 3                                   53141.663800
# 4                                   40988.684440
# 5                                   47320.635370
# 6                                   32610.079580
# 7                                   57715.170560
# 8                                   65097.941320
# 9                                    5065.308510
# 10                                  11238.993450
# 11                                  15656.057160
# 12                                 104924.289200
# 13                                  86504.199460
# 14                                  39598.294700
# 15                                  37499.793020
# 16                                  49076.955630
# 17                                  38217.142860
# 18                                  20952.714870
# 19                                  32287.346940
#
#     LogicalDisk._Total..pct_.Disk.Write.Time  \
# 0                                  13.487612
# 1                                  15.756429
# 2                                  40.177378
# 3                                  25.906233
# 4                                  10.383619
# 5                                  15.179443
# 6                                   7.206940
# 7                                   4.843659
# 8                                   9.854080
# 9                                   0.424339
# 10                                  2.056146
# 11                                  0.050356
# 12                                  0.959991
# 13                                  0.790296
# 14                                  0.599613
# 15                                  5.234501
# 16                                  4.182377
# 17                                  1.333564
# 18                                  1.868816
# 19                                  0.551928
#
#     LogicalDisk._Total..Avg..Disk.sec.Transfer  label
# 0                                     0.000405      0
# 1                                     0.000533      0
# 2                                     0.001028      0
# 3                                     0.001099      0
# 4                                     0.000913      0
# 5                                     0.001021      0
# 6                                     0.000981      0
# 7                                     0.000467      0
# 8                                     0.000573      0
# 9                                     0.000264      0
# 10                                    0.000575      0
# 11                                    0.000302      0
# 12                                    0.000642      0
# 13                                    0.000779      0
# 14                                    0.000505      0
# 15                                    0.001028      0
# 16                                    0.001445      0
# 17                                    0.001249      0
# 18                                    0.000447      0
# 19                                    0.000414      0
#
# [20 rows x 106 columns]

# %% [markdown]
# # Making the data balance

# %%
#df = df_new

# %%
freq = df['label'].value_counts()
freq
# Out:
# 0    24283
# 1    10931
# Name: label, dtype: int64

# %%
def autopct_format(values):
        def my_format(pct):
            total = sum(values)
            val = int(round(pct*total/100.0))
            return '{:.1f}%\n({v:d})'.format(pct, v=val)
        return my_format

#plt.pie(mydata,labels = mylabels, autopct=autopct_format(mydata))

# %%
import matplotlib.pyplot as plt
import seaborn
  
# declaring data
data = [24283, 10931]
keys = ['Normal', 'Under Attack']
  
# declaring exploding pie
explode = [0, 0.1]
# define Seaborn color palette to use
palette_color = seaborn.color_palette('pastel')
  
# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct=autopct_format(data))
  
# displaying chart
plt.show()

# %%
freq = df['label'].value_counts()
delete_frac = round((freq[0] - freq[1])/freq[0],2)
df = df.drop(df.query('label == 0').sample(frac= delete_frac).index)
df['label'].value_counts()
# Out:
# 1    10931
# 0    10927
# Name: label, dtype: int64

# %%
df.shape
# Out:
# (21858, 106)

# %% [markdown]
# # Investigating the correlation

# %%
X = df.iloc[:,0:105]

# %%
cormat = X.corr()
round(cormat,2)
# Out:
#                                               Processor_DPC_Rate  \
# Processor_DPC_Rate                                          1.00
# Processor_pct_.Idle_Time                                   -0.25
# Processor_pct_.Interrupt_Time                               0.06
# Processor_pct_.User_Time                                    0.03
# Processor_pct_.C1_Time                                     -0.25
# ...                                                          ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                    0.54
# LogicalDisk._Total..Disk.Transfers.sec                      0.76
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                0.00
# LogicalDisk._Total..pct_.Disk.Write.Time                    0.05
# LogicalDisk._Total..Avg..Disk.sec.Transfer                  0.00
#
#                                               Processor_pct_.Idle_Time  \
# Processor_DPC_Rate                                               -0.25
# Processor_pct_.Idle_Time                                          1.00
# Processor_pct_.Interrupt_Time                                    -0.43
# Processor_pct_.User_Time                                         -0.85
# Processor_pct_.C1_Time                                            1.00
# ...                                                                ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                         -0.32
# LogicalDisk._Total..Disk.Transfers.sec                           -0.31
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                     -0.03
# LogicalDisk._Total..pct_.Disk.Write.Time                         -0.05
# LogicalDisk._Total..Avg..Disk.sec.Transfer                       -0.11
#
#                                               Processor_pct_.Interrupt_Time  \
# Processor_DPC_Rate                                                     0.06
# Processor_pct_.Idle_Time                                              -0.43
# Processor_pct_.Interrupt_Time                                          1.00
# Processor_pct_.User_Time                                               0.20
# Processor_pct_.C1_Time                                                -0.43
# ...                                                                     ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                               0.15
# LogicalDisk._Total..Disk.Transfers.sec                                 0.03
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                           0.11
# LogicalDisk._Total..pct_.Disk.Write.Time                               0.09
# LogicalDisk._Total..Avg..Disk.sec.Transfer                             0.10
#
#                                               Processor_pct_.User_Time  \
# Processor_DPC_Rate                                                0.03
# Processor_pct_.Idle_Time                                         -0.85
# Processor_pct_.Interrupt_Time                                     0.20
# Processor_pct_.User_Time                                          1.00
# Processor_pct_.C1_Time                                           -0.85
# ...                                                                ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                          0.09
# LogicalDisk._Total..Disk.Transfers.sec                            0.06
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                      0.05
# LogicalDisk._Total..pct_.Disk.Write.Time                          0.01
# LogicalDisk._Total..Avg..Disk.sec.Transfer                        0.08
#
#                                               Processor_pct_.C1_Time  \
# Processor_DPC_Rate                                             -0.25
# Processor_pct_.Idle_Time                                        1.00
# Processor_pct_.Interrupt_Time                                  -0.43
# Processor_pct_.User_Time                                       -0.85
# Processor_pct_.C1_Time                                          1.00
# ...                                                              ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                       -0.32
# LogicalDisk._Total..Disk.Transfers.sec                         -0.31
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                   -0.03
# LogicalDisk._Total..pct_.Disk.Write.Time                       -0.05
# LogicalDisk._Total..Avg..Disk.sec.Transfer                     -0.11
#
#                                               Processor_pct_.Processor_Time  \
# Processor_DPC_Rate                                                     0.19
# Processor_pct_.Idle_Time                                              -0.99
# Processor_pct_.Interrupt_Time                                          0.42
# Processor_pct_.User_Time                                               0.87
# Processor_pct_.C1_Time                                                -0.99
# ...                                                                     ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                               0.27
# LogicalDisk._Total..Disk.Transfers.sec                                 0.25
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                           0.04
# LogicalDisk._Total..pct_.Disk.Write.Time                               0.02
# LogicalDisk._Total..Avg..Disk.sec.Transfer                             0.09
#
#                                               Processor_C1_ransitions_sec  \
# Processor_DPC_Rate                                                   0.71
# Processor_pct_.Idle_Time                                            -0.20
# Processor_pct_.Interrupt_Time                                        0.06
# Processor_pct_.User_Time                                            -0.07
# Processor_pct_.C1_Time                                              -0.20
# ...                                                                   ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                             0.70
# LogicalDisk._Total..Disk.Transfers.sec                               0.89
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                         0.02
# LogicalDisk._Total..pct_.Disk.Write.Time                             0.13
# LogicalDisk._Total..Avg..Disk.sec.Transfer                          -0.02
#
#                                               Processor_pct_.DPC_Time  \
# Processor_DPC_Rate                                               0.46
# Processor_pct_.Idle_Time                                        -0.43
# Processor_pct_.Interrupt_Time                                    0.50
# Processor_pct_.User_Time                                         0.16
# Processor_pct_.C1_Time                                          -0.43
# ...                                                               ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                         0.33
# LogicalDisk._Total..Disk.Transfers.sec                           0.42
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                     0.17
# LogicalDisk._Total..pct_.Disk.Write.Time                         0.02
# LogicalDisk._Total..Avg..Disk.sec.Transfer                       0.05
#
#                                               Processor_pct_.Privileged_Time  \
# Processor_DPC_Rate                                                      0.33
# Processor_pct_.Idle_Time                                               -0.76
# Processor_pct_.Interrupt_Time                                           0.54
# Processor_pct_.User_Time                                                0.32
# Processor_pct_.C1_Time                                                 -0.76
# ...                                                                      ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                0.38
# LogicalDisk._Total..Disk.Transfers.sec                                  0.41
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                            0.01
# LogicalDisk._Total..pct_.Disk.Write.Time                                0.02
# LogicalDisk._Total..Avg..Disk.sec.Transfer                              0.06
#
#                                               Processor_DPCs_Queued_sec  ...  \
# Processor_DPC_Rate                                                 0.79  ...
# Processor_pct_.Idle_Time                                          -0.31  ...
# Processor_pct_.Interrupt_Time                                      0.10  ...
# Processor_pct_.User_Time                                           0.03  ...
# Processor_pct_.C1_Time                                            -0.31  ...
# ...                                                                 ...  ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                           0.65  ...
# LogicalDisk._Total..Disk.Transfers.sec                             0.94  ...
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                       0.01  ...
# LogicalDisk._Total..pct_.Disk.Write.Time                           0.07  ...
# LogicalDisk._Total..Avg..Disk.sec.Transfer                         0.00  ...
#
#                                               LogicalDisk._Total..pct_.Disk.Time  \
# Processor_DPC_Rate                                                          0.53
# Processor_pct_.Idle_Time                                                   -0.22
# Processor_pct_.Interrupt_Time                                               0.11
# Processor_pct_.User_Time                                                    0.03
# Processor_pct_.C1_Time                                                     -0.22
# ...                                                                          ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                    0.64
# LogicalDisk._Total..Disk.Transfers.sec                                      0.64
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                0.02
# LogicalDisk._Total..pct_.Disk.Write.Time                                    0.67
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                  0.35
#
#                                               LogicalDisk._Total..Avg..Disk.Bytes.Read  \
# Processor_DPC_Rate                                                                0.02
# Processor_pct_.Idle_Time                                                         -0.20
# Processor_pct_.Interrupt_Time                                                     0.06
# Processor_pct_.User_Time                                                          0.21
# Processor_pct_.C1_Time                                                           -0.20
# ...                                                                                ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                          0.19
# LogicalDisk._Total..Disk.Transfers.sec                                            0.02
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                      0.21
# LogicalDisk._Total..pct_.Disk.Write.Time                                          0.14
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                        0.10
#
#                                               LogicalDisk._Total..Avg..Disk.Write.Queue.Length  \
# Processor_DPC_Rate                                                                        0.12
# Processor_pct_.Idle_Time                                                                 -0.11
# Processor_pct_.Interrupt_Time                                                             0.11
# Processor_pct_.User_Time                                                                  0.03
# Processor_pct_.C1_Time                                                                   -0.11
# ...                                                                                        ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                                  0.35
# LogicalDisk._Total..Disk.Transfers.sec                                                    0.17
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                              0.04
# LogicalDisk._Total..pct_.Disk.Write.Time                                                  0.99
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                                0.46
#
#                                               LogicalDisk._Total..Avg..Disk.Queue.Length  \
# Processor_DPC_Rate                                                                  0.70
# Processor_pct_.Idle_Time                                                           -0.26
# Processor_pct_.Interrupt_Time                                                       0.05
# Processor_pct_.User_Time                                                            0.03
# Processor_pct_.C1_Time                                                             -0.26
# ...                                                                                  ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                            0.68
# LogicalDisk._Total..Disk.Transfers.sec                                              0.84
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                       -0.01
# LogicalDisk._Total..pct_.Disk.Write.Time                                            0.32
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                          0.18
#
#                                               LogicalDisk._Total..pct_.Disk.Read.Time  \
# Processor_DPC_Rate                                                               0.66
# Processor_pct_.Idle_Time                                                        -0.26
# Processor_pct_.Interrupt_Time                                                    0.08
# Processor_pct_.User_Time                                                         0.04
# Processor_pct_.C1_Time                                                          -0.26
# ...                                                                               ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                         0.65
# LogicalDisk._Total..Disk.Transfers.sec                                           0.79
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                    -0.01
# LogicalDisk._Total..pct_.Disk.Write.Time                                         0.19
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                       0.14
#
#                                               LogicalDisk._Total..Disk.Write.Bytes.sec  \
# Processor_DPC_Rate                                                                0.54
# Processor_pct_.Idle_Time                                                         -0.32
# Processor_pct_.Interrupt_Time                                                     0.15
# Processor_pct_.User_Time                                                          0.09
# Processor_pct_.C1_Time                                                           -0.32
# ...                                                                                ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                          1.00
# LogicalDisk._Total..Disk.Transfers.sec                                            0.67
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                      0.13
# LogicalDisk._Total..pct_.Disk.Write.Time                                          0.27
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                        0.08
#
#                                               LogicalDisk._Total..Disk.Transfers.sec  \
# Processor_DPC_Rate                                                              0.76
# Processor_pct_.Idle_Time                                                       -0.31
# Processor_pct_.Interrupt_Time                                                   0.03
# Processor_pct_.User_Time                                                        0.06
# Processor_pct_.C1_Time                                                         -0.31
# ...                                                                              ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                        0.67
# LogicalDisk._Total..Disk.Transfers.sec                                          1.00
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                   -0.03
# LogicalDisk._Total..pct_.Disk.Write.Time                                        0.08
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                     -0.01
#
#                                               LogicalDisk._Total..Avg..Disk.Bytes.Transfer  \
# Processor_DPC_Rate                                                                    0.00
# Processor_pct_.Idle_Time                                                             -0.03
# Processor_pct_.Interrupt_Time                                                         0.11
# Processor_pct_.User_Time                                                              0.05
# Processor_pct_.C1_Time                                                               -0.03
# ...                                                                                    ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                              0.13
# LogicalDisk._Total..Disk.Transfers.sec                                               -0.03
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                          1.00
# LogicalDisk._Total..pct_.Disk.Write.Time                                              0.04
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                            0.11
#
#                                               LogicalDisk._Total..pct_.Disk.Write.Time  \
# Processor_DPC_Rate                                                                0.05
# Processor_pct_.Idle_Time                                                         -0.05
# Processor_pct_.Interrupt_Time                                                     0.09
# Processor_pct_.User_Time                                                          0.01
# Processor_pct_.C1_Time                                                           -0.05
# ...                                                                                ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                          0.27
# LogicalDisk._Total..Disk.Transfers.sec                                            0.08
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                      0.04
# LogicalDisk._Total..pct_.Disk.Write.Time                                          1.00
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                        0.47
#
#                                               LogicalDisk._Total..Avg..Disk.sec.Transfer
# Processor_DPC_Rate                                                                  0.00
# Processor_pct_.Idle_Time                                                           -0.11
# Processor_pct_.Interrupt_Time                                                       0.10
# Processor_pct_.User_Time                                                            0.08
# Processor_pct_.C1_Time                                                             -0.11
# ...                                                                                  ...
# LogicalDisk._Total..Disk.Write.Bytes.sec                                            0.08
# LogicalDisk._Total..Disk.Transfers.sec                                             -0.01
# LogicalDisk._Total..Avg..Disk.Bytes.Transfer                                        0.11
# LogicalDisk._Total..pct_.Disk.Write.Time                                            0.47
# LogicalDisk._Total..Avg..Disk.sec.Transfer                                          1.00
#
# [105 rows x 105 columns]

# %%
import seaborn as sns
mask = np.triu(np.ones_like(X.corr().abs(), dtype=np.bool))

heatmap = sns.heatmap(X.corr().abs(),annot=False,cmap='BrBG')
heatmap.set_title('Correlation between independent variables', fontdict={'fontsize':12}, pad=10);

# %%
# calculate the correlation matrix and reshape
df_corr = X.corr().abs().stack().reset_index()

# rename the columns
df_corr.columns = ['FEATURE_1', 'FEATURE_2', 'CORRELATION']
df_corr.head()
# Out:
#             FEATURE_1                      FEATURE_2  CORRELATION
# 0  Processor_DPC_Rate             Processor_DPC_Rate     1.000000
# 1  Processor_DPC_Rate       Processor_pct_.Idle_Time     0.248197
# 2  Processor_DPC_Rate  Processor_pct_.Interrupt_Time     0.062023
# 3  Processor_DPC_Rate       Processor_pct_.User_Time     0.034466
# 4  Processor_DPC_Rate         Processor_pct_.C1_Time     0.248197

# %%
df_corr = df_corr[df_corr['FEATURE_1'] != df_corr['FEATURE_2']]

# %%
df_corr_perfect = df_corr[df_corr.CORRELATION == 1]

# %%
df_corr_perfect
# Out:
#                                               FEATURE_1  \
# 108                            Processor_pct_.Idle_Time
# 417                              Processor_pct_.C1_Time
# 1685                            Process_Page_File.Bytes
# 2200                              Process_Private_Bytes
# 4099  Network_I.Intel.R._82574L_GNC..Packets.Sent.Un...
# 4204  Network_I.Intel.R._82574L_GNC..Packets.Receive...
# 4511    Network_I.Intel.R._82574L_GNC..Packets.Sent.sec
# 4616  Network_I.Intel.R._82574L_GNC..Packets.Receive...
# 5151                             Memory.Available.Bytes
# 5769                            Memory.Available.KBytes
#
#                                               FEATURE_2  CORRELATION
# 108                              Processor_pct_.C1_Time          1.0
# 417                            Processor_pct_.Idle_Time          1.0
# 1685                              Process_Private_Bytes          1.0
# 2200                            Process_Page_File.Bytes          1.0
# 4099    Network_I.Intel.R._82574L_GNC..Packets.Sent.sec          1.0
# 4204  Network_I.Intel.R._82574L_GNC..Packets.Receive...          1.0
# 4511  Network_I.Intel.R._82574L_GNC..Packets.Sent.Un...          1.0
# 4616  Network_I.Intel.R._82574L_GNC..Packets.Receive...          1.0
# 5151                            Memory.Available.KBytes          1.0
# 5769                             Memory.Available.Bytes          1.0

# %%
df_corr_perfect = df_corr_perfect.drop([417, 2200,4204,4616,5769])

# %%
df_corr_perfect
# Out:
#                                               FEATURE_1  \
# 108                            Processor_pct_.Idle_Time
# 1685                            Process_Page_File.Bytes
# 4099  Network_I.Intel.R._82574L_GNC..Packets.Sent.Un...
# 4511    Network_I.Intel.R._82574L_GNC..Packets.Sent.sec
# 5151                             Memory.Available.Bytes
#
#                                               FEATURE_2  CORRELATION
# 108                              Processor_pct_.C1_Time          1.0
# 1685                              Process_Private_Bytes          1.0
# 4099    Network_I.Intel.R._82574L_GNC..Packets.Sent.sec          1.0
# 4511  Network_I.Intel.R._82574L_GNC..Packets.Sent.Un...          1.0
# 5151                            Memory.Available.KBytes          1.0

# %%
lst1 = df_corr_perfect.FEATURE_1
remove_var = list(set(lst1))

# %%
df = df.drop(remove_var, axis=1)

# %%
df.shape
# Out:
# (21858, 101)

# %% [markdown]
# ## Seperating independent and dependent variables:

# %%
# Removing Y and Id
X = df.iloc [: ,:-1].values    # independent variables
# Keeping only Y
y = df.iloc [: , -1].values    # dependent variables

# %% [markdown]
# ## Handling Inf values:

# %%
import numpy as np

# find min and max values for each column, ignoring nan, -inf, and inf
mins = [np.nanmin(X[:, i][X[:, i] != -np.inf]) for i in range(X.shape[1])]
maxs = [np.nanmax(X[:, i][X[:, i] != np.inf]) for i in range(X.shape[1])]

# go through matrix one column at a time and replace  + and -infinity 
# with the max or min for that column
for i in range(X.shape[1]):
    X[:, i][X[:, i] == -np.inf] = mins[i]
    X[:, i][X[:, i] == np.inf] = maxs[i]

# %% [markdown]
# ## Standardizing all numerical columns

# %%
# feature Scaling
sc = MinMaxScaler(feature_range = (0,1))
X = sc.fit_transform(X)

# %% [markdown]
# # Train test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y,test_size=0.2)

# %% [markdown]
# # Supervised Model selection

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [10,20,50],
            'kernel': ['rbf','poly','sigmoid','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [50,100,200],
            'max_features': ['auto', 'sqrt', 'log2'],
            'max_depth' : [5,15,25],
            'criterion' : ['gini', 'entropy']
        }
    }
}

# %%
import time
start = time.time()

scores = []

for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])


end = time.time()
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)


print("Execution time: "+"{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# Execution time: 00:42:09.34

# %%
df
# Out:
#            model  best_score  \
# 0            svm    0.968946
# 1  random_forest    0.986789
#
#                                          best_params
# 0                      {'C': 50, 'kernel': 'linear'}
# 1  {'criterion': 'entropy', 'max_depth': 25, 'max...

# %%
df.best_params[1]
# Out:
# {'criterion': 'entropy',
#  'max_depth': 25,
#  'max_features': 'sqrt',
#  'n_estimators': 200}

# %%
forest=RandomForestClassifier( n_estimators= 200, max_depth=25, criterion='entropy',max_features = 'sqrt')
forest.fit(X_train, y_train)
# Measure model performance
y_pred = forest.predict(X_test)
print('Test Accuracy: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Test Accuracy: 0.991

# %% [markdown]
# Between the two supervised model random forest is the clear winner and the test accuracy is 99.1%.

# %% [markdown]
# # Unsupervised modelling:

# %% [markdown]
# ## SOM

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Minisom library and module is used for performing Self Organizing Maps
from minisom import MiniSom

# %%
def classify(som, data):
    """Classifies each sample in data in one of the classes definited
    using the method labels_map.
    Returns a list of the same length of data where the i-th element
    is the class assigned to data[i].
    """
    winmap = som.labels_map(X_train, y_train)
    default_class = np.sum(list(winmap.values())).most_common()[0][0]
    result = []
    for d in data:
        win_position = som.winner(d)
        if win_position in winmap:
            result.append(winmap[win_position].most_common()[0][0])
        else:
            result.append(default_class)
    return result

# %%
som_shape = (1, 2)
som = MiniSom(som_shape[0], som_shape[1], X_train.shape[1],sigma = 4, learning_rate=0.5, 
              neighborhood_function='triangle')
som.pca_weights_init(X_train)
som.train_random(X_train, 100, verbose=False)

print(classification_report(y_test, classify(som, X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.68      0.80      2186
#            1       0.75      0.97      0.85      2186
#
#     accuracy                           0.83      4372
#    macro avg       0.86      0.83      0.82      4372
# weighted avg       0.86      0.83      0.82      4372

# %% [markdown]
# ## K-means clustering

# %%
#Now let's open it with pandas
import pandas as pd
from pandas import Series,DataFrame
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

import numpy as np
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc
from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn import metrics 


import warnings
warnings.filterwarnings('ignore')

# %%
def k_means_fit(covariates,centroid_method):
    data = pd.DataFrame(covariates)
    # from sklearn.cluster import KMeans 
    clusters = 2
    number_of_iteration = 100
    kmeans = KMeans(n_clusters = clusters,n_init= number_of_iteration,init = centroid_method,algorithm = "full") 
    kmeans.fit(data) 
    
    y_labels_test = kmeans.predict(X_test)
    tab = pd.crosstab(index=y_test, columns=y_labels_test)
    print (metrics.classification_report(y_test,y_labels_test))

# %%
k_means_fit(X_train,centroid_method = "random")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.68      0.81      2186
#            1       0.76      1.00      0.86      2186
#
#     accuracy                           0.84      4372
#    macro avg       0.88      0.84      0.84      4372
# weighted avg       0.88      0.84      0.84      4372

# %% [markdown]
# # Hierchical clustering

# %%
from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')  
cluster.fit_predict(X_test)
print (metrics.classification_report(y_test,cluster.labels_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76      2186
#            1       0.74      0.88      0.80      2186
#
#     accuracy                           0.79      4372
#    macro avg       0.80      0.79      0.78      4372
# weighted avg       0.80      0.79      0.78      4372

# %% [markdown]
# # Result

# %% [markdown]
# Among these three clustering methods K-means clustering giving us the best classification accuracy which is 84%.
